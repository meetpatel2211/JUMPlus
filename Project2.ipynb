# %% [markdown]
# 1. Importing required libraries

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np
import plotly.graph_objs as go
import plotly.offline as py

# %% [markdown]
# Function to see Max rows

# %%
def maxrows():
    pd.set_option('display.max_rows', None)

# %% [markdown]
# 2. Reading in the CSV and 3. Showing first 5 records from CSV

# %%
data = pd.read_csv('charcters_stats.csv')
data.head(5)
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 4  Abomination       bad            63        80     53          90     55
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 4      95    436

# %% [markdown]
# 4. Showing the number of rows and cloumns

# %%
print(f'There are {data.shape[0]} rows and {data.shape[1]} Columns')
# Out:
# There are 611 rows and 9 Columns

# %% [markdown]
# 5. Finding how many good, bad, neutral aligments are

# %%
cnt = data['Alignment'].value_counts()
cnt
# Out:
# good       432
# bad        165
# neutral     11
# Name: Alignment, dtype: int64

# %% [markdown]
# 6. Finding all the good alignment superheroes

# %%
good = data.loc[data['Alignment'] == 'good']
maxrows()
good
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0              3-D Man      good            50        31     43          32
# 1               A-Bomb      good            38       100     17          80
# 2           Abe Sapien      good            88        14     35          42
# 3             Abin Sur      good            50        90     53          64
# 6          Adam Monroe      good            63        10     12         100
# 7         Adam Strange      good             1         1      1           1
# 8            Agent  13      good             1         1      1           1
# 9            Agent Bob      good            10         8     13           5
# 10          Agent Zero      good            75        28     38          80
# 12          Alan Scott      good            63        80     23          90
# 13        Alex Woolsly      good             1         1      1           1
# ...

# %% [markdown]
# 7. Showing only the 5 superheroes from alignment good

# %%
good.head(5)
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 6  Adam Monroe      good            63        10     12         100     71
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 6      64    320

# %% [markdown]
# 8. Showing top 5 records were speed is the higest for all the good alignment super heroes

# %%
good.nlargest(5, 'Speed')
# Out:
#            Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 85   Black Bolt      good            75        67    100          84    100
# 229     Flash I      good            63        10    100          50     57
# 230    Flash II      good            63        10    100          60     66
# 231   Flash III      good            63        10    100          60     83
# 232    Flash IV      good            63        10    100          32     59
#
#      Combat  Total
# 85       56    482
# 229      32    312
# 230      32    331
# 231      32    348
# 232      48    312

# %% [markdown]
# 9. Showing top 5 records of super heroes who have maximum power of good alignment

# %%
good.nlargest(5, 'Power')
# Out:
#               Name Alignment  Intelligence  Strength  Speed  Durability  \
# 69   Beta Ray Bill      good            63        80     35          95
# 70        Beyonder      good            88       100     23         100
# 85      Black Bolt      good            75        67    100          84
# 129          Cable      good            88        48     23          56
# 185        Deadman      good            50        10     33         100
#
#      Power  Combat  Total
# 69     100      84    457
# 70     100      56    467
# 85     100      56    482
# 129    100      80    395
# 185    100      42    335

# %% [markdown]
# 10. Fiding how many super hereoes are there with power 100 of good alignments

# %%
Max_power = good.nlargest(5, 'Power', keep='all')
print(f"There are {Max_power.shape[0]} Max power heroes")
# Out:
# There are 33 Max power heroes

# %% [markdown]
# 11. Shape of all max power heroes

# %%
Max_power.shape
# Out:
# (33, 9)

# %% [markdown]
# 12. Showing all records of Max power superheroes

# %%
maxrows()
Max_power
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 69       Beta Ray Bill      good            63        80     35          95
# 70            Beyonder      good            88       100     23         100
# 85          Black Bolt      good            75        67    100          84
# 129              Cable      good            88        48     23          56
# 185            Deadman      good            50        10     33         100
# 196        Doctor Fate      good            81        16     25          80
# 198     Doctor Strange      good           100        10     12          84
# 204       Dr Manhattan      good            88        32     42          95
# 226          Firestorm      good            50        53     58          56
# 251               Goku      good            56       100     75          90
# 266         Hal Jordan      good            63        90     53          64
# ...

# %% [markdown]
# 13. This are top 5 total values of max power supoerheroes

# %%
Max_power[['Name','Total','Power','Alignment']].head(5)
# Out:
#               Name  Total  Power Alignment
# 69   Beta Ray Bill    457    100      good
# 70        Beyonder    467    100      good
# 85      Black Bolt    482    100      good
# 129          Cable    395    100      good
# 185        Deadman    335    100      good

# %% [markdown]
# 14. Showing bar plot of top 5 max power super heroes and there total stats

# %%
df = Max_power.nlargest(5, 'Power')
ax = sns.barplot(data=df, x='Name', y='Total', order=df.sort_values('Total').Name)
for i in ax.containers:
    ax.bar_label(i,)

# %% [markdown]
# 15. Extracting all villains that have bad alignment

# %%
bad = data.loc[data['Alignment'] == 'bad']
bad
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 4          Abomination       bad            63        80     53          90
# 5              Abraxas       bad            88       100     83          99
# 11          Air-Walker       bad            50        85    100          85
# 16               Amazo       bad            75       100    100         100
# 17                Ammo       bad             1         1      1           1
# 21              Angela       bad             1         1      1           1
# 23           Annihilus       bad            75        80     47          56
# 26        Anti-Monitor       bad            88        90     38          90
# 27          Anti-Spawn       bad             1         1      1           1
# 29          Apocalypse       bad           100       100     33         100
# 35            Arclight       bad            38        63     23          42
# ...

# %% [markdown]
# 16. Showing first 5 records of the bad alignment superheroes

# %%
bad.head(5)
# Out:
#            Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 4   Abomination       bad            63        80     53          90     55
# 5       Abraxas       bad            88       100     83          99    100
# 11   Air-Walker       bad            50        85    100          85    100
# 16        Amazo       bad            75       100    100         100    100
# 17         Ammo       bad             1         1      1           1      0
#
#     Combat  Total
# 4       95    436
# 5       56    526
# 11      40    460
# 16     100    575
# 17       1      5

# %% [markdown]
# 17. Showing top 5 fastest super villains in terms of super speed

# %%
bad.nlargest(5, 'Speed')
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 11       Air-Walker       bad            50        85    100          85
# 16            Amazo       bad            75       100    100         100
# 535  Superboy-Prime       bad            94       100    100         100
# 610            Zoom       bad            50        10    100          28
# 242     General Zod       bad            94       100     96         100
#
#      Power  Combat  Total
# 11     100      40    460
# 16     100     100    575
# 535    100      85    579
# 610     72      28    288
# 242     94      95    579

# %% [markdown]
# 18. Showing top 5 super villains in terms of intelligence

# %%
bad.nlargest(5, 'Intelligence')
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 386  Mister Mxyzptlk       bad           113        10     12          14
# 29        Apocalypse       bad           100       100     33         100
# 122         Brainiac       bad           100        28     63          90
# 194      Doctor Doom       bad           100        32     20         100
# 315            Joker       bad           100        10     12          56
#
#      Power  Combat  Total
# 386    100      28    277
# 29     100      60    493
# 122     60      75    416
# 194     93      84    429
# 315     22      90    290

# %% [markdown]
# 19. Showing who is the most dangerous super villain after calculating their total.

# %%
bad.nlargest(5, 'Total')
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 242     General Zod       bad            94       100     96         100
# 535  Superboy-Prime       bad            94       100    100         100
# 16            Amazo       bad            75       100    100         100
# 203        Dormammu       bad            88        95     83         100
# 201        Doomsday       bad            88        80     67         120
#
#      Power  Combat  Total
# 242     94      95    579
# 535    100      85    579
# 16     100     100    575
# 203    100      80    546
# 201    100      90    545

# %% [markdown]
# 20. Showing a histogram for the distribution of speed in only good alignment super heroes

# %%
speed = good
plt.figure(figsize=(10,5))
sns.histplot(data=speed, x='Speed').set(title='Distribution of speed')
# Out:
# [Text(0.5, 1.0, 'Distribution of speed')]

# %% [markdown]
# 21. Showing the histogram for combat distribution for all the bad alignment super heroes

# %%
speed = bad
plt.figure(figsize=(10,5))
sns.histplot(data=speed, x='Combat').set(title='Distribution of combat')
# Out:
# [Text(0.5, 1.0, 'Distribution of combat')]

# %%
data_x= data[['Intelligence','Strength','Speed','Durability','Power','Combat']]
avg = data.groupby('Alignment')[['Total']].mean().round(2)

# %%
label = ['good', 'bad', 'neutral']
explode = [.5 if Alignment == 'neutral' else 0 for Alignment in cnt.index]
plt.pie(cnt, labels=label, autopct="%.2f%%", shadow=True, startangle=30, explode=explode)
plt.title('Percentage of Alignment of super heroes')

plt.show()

# %%
plt.style.use('ggplot')
f, ax = plt.subplots(figsize=(11, 15))

ax.set_facecolor('#fafafa')
ax.set(xlim=(-0.5, 140))
plt.ylabel('Variables')
plt.title('Overview of the Stats')
ax = sns.boxplot(data=data_x, orient='h', palette='Set2')

# %%
correlation = data_x.corr()
matrix_cols = correlation.columns.tolist()

corr_array  = np.array(correlation)
trace = go.Heatmap(z = corr_array,
                    x = matrix_cols,
                    y = matrix_cols,
                    colorscale='Viridis',
                    colorbar   = dict() ,
                    )
layout = go.Layout(dict(title = 'Correlation Matrix for variables',
                        #autosize = False,
                        #height  = 1400,
                        #width   = 1600,
                        margin  = dict(r = 0 ,l = 100,
                                        t = 0,b = 100,
                                        ),
                        yaxis   = dict(tickfont = dict(size = 9)),
                        xaxis   = dict(tickfont = dict(size = 9)),
                        )
                    )
fig = go.Figure(data = [trace],layout = layout)
py.iplot(fig)

# %%
batman = data.loc[data['Name'] == 'Batman']
spiderman = data.loc[data['Name'] == 'Spiderman']

# %%
ax = plt.subplot()

ax = sns.barplot(x=data_x, y=batman, color='b')
ax = sns.barplot(x=data_x, y=spiderman, color='r')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13928\1834683203.py in <module>
#       1 ax = plt.subplot()
#       2
# ----> 3 ax = sns.barplot(x=data_x, y=batman, color='b')
#       4 ax = sns.barplot(x=data_x, y=spiderman, color='r')
#       5
#
# c:\Users\meetp\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# c:\Users\meetp\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3180 ):
#    3181
# ...
